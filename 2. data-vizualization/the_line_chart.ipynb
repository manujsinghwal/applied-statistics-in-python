# %% [markdown]
# <a href="https://colab.research.google.com/github/manujsinghwal/applied-statistics/blob/main/2.%20data-vizualization/the_line_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Line Chart
# A line chart, also referred to as a line graph or a line plot, connects a series of data points using a line. This chart type presents sequential values to help us identify trends. Most of the time, the x-axis (horizontal axis) represents a sequential progression of values. The y-axis (vertical axis) then tells us the values for a selected metric across that progression. This is a common chart and is great to use when we want to show data over time.
#
# Let's take an example of data and try to plot a line chart on that.

# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Creating a dataframe
df = pd.DataFrame(
    {
        'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
        'ProductSalesInThousand':[18, 17.5, 19, 17, 16.5, 17.5, 19, 20, 22, 21.5, 23, 23.5]
    }
)
df
# Out:
#    Month  ProductSalesInThousand
# 0    Jan                    18.0
# 1    Feb                    17.5
# 2    Mar                    19.0
# 3    Apr                    17.0
# 4    May                    16.5
# 5    Jun                    17.5
# 6    Jul                    19.0
# 7    Aug                    20.0
# 8    Sep                    22.0
# 9    Oct                    21.5
# 10   Nov                    23.0
# 11   Dec                    23.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Month                   12 non-null     object
#  1   ProductSalesInThousand  12 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 320.0+ bytes

# %%
# Setting up some customizations
plt.figure(figsize=(8, 5))  # Setting the figure size
sns.set(style='darkgrid')

# %%
# Ploting the line graph
sns.lineplot(
    data=df,
    x='Month',
    y='ProductSalesInThousand',
    marker='o'
    )

# Adding labels and title
plt.xlabel('\nMonth')
plt.ylabel('Product Sales In Thousand\n')
plt.title('Product Sales Over Months\n')

# Showing the plot
plt.show()
